# %%
import numpy as np
import pandas as pd

# %%
dataSales = pd.read_excel("sales_data_sample.xlsx", engine="openpyxl", header=0)
dataSales
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#                 ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0          2/24/2003 0:00   Shipped       1         2     2003  ...
# 1     2003-07-05 00:00:00   Shipped       2         5     2003  ...
# 2     2003-01-07 00:00:00   Shipped       3         7     2003  ...
# 3          8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     2003-10-10 00:00:00   Shipped       4        10     2003  ...
# ...                   ...       ...     ...       ...      ...  ...
# 2818  2004-02-12 00:00:00   Shipped       4        12     2004  ...
# 2819       1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820  2005-01-03 00:00:00  Resolved       1         3     2005  ...
# 2821       3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822  2005-06-05 00:00:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
SalesperYr = dataSales[["YEAR_ID", "SALES"]].groupby(["YEAR_ID"])["SALES"].sum().reset_index()
SalesperYr["YEAR_ID"] = SalesperYr["YEAR_ID"].astype("string")

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(SalesperYr["YEAR_ID"], SalesperYr["SALES"], color=("blue", "red", "yellow"))
plt.title("Sales per Year")
plt.ylabel("Sales")
plt.show()

# %%
SalesperCnt = dataSales[["COUNTRY", "SALES"]].groupby(["COUNTRY"])["SALES"].sum().reset_index()

plt.bar(SalesperCnt["COUNTRY"], SalesperCnt["SALES"])
plt.title("Sales per Country")
plt.ylabel("Sales")
plt.show()

# %%
plt.pie(SalesperCnt["SALES"], labels=SalesperCnt["COUNTRY"],autopct="%%1.1f%%", startangle=90)
plt.show()

# %%
topSales = SalesperCnt.nlargest(5, ["SALES"])
plt.pie(topSales["SALES"], labels=topSales["COUNTRY"],autopct="%1.1f%%", startangle=90, explode=(0.1, 0, 0, 0, 0))
plt.title("Top 5 Sales")
plt.show()

# %%
dataSales["MonthYear"] = pd.to_datetime(dataSales["YEAR_ID"].astype("string") + dataSales["MONTH_ID"].astype("string"), format="%Y%m")

SalesMY = dataSales[["MonthYear", "SALES"]].groupby(["MonthYear"])["SALES"].sum().reset_index()
SalesMY
# Out:
#     MonthYear       SALES
# 0  2003-01-01   129753.60
# 1  2003-02-01   140836.19
# 2  2003-03-01   174504.90
# 3  2003-04-01   201609.55
# 4  2003-05-01   192673.11
# 5  2003-06-01   168082.56
# 6  2003-07-01   187731.88
# 7  2003-08-01   197809.30
# 8  2003-09-01   263973.36
# 9  2003-10-01   568290.97
# 10 2003-11-01  1029837.66
# 11 2003-12-01   261876.46
# 12 2004-01-01   316577.42
# 13 2004-02-01   311419.53
# 14 2004-03-01   205733.73
# 15 2004-04-01   206148.12
# 16 2004-05-01   273438.39
# 17 2004-06-01   286674.22
# 18 2004-07-01   327144.09
# 19 2004-08-01   461501.27
# 20 2004-09-01   320750.91
# 21 2004-10-01   552924.25
# 22 2004-11-01  1089048.01
# 23 2004-12-01   372802.66
# 24 2005-01-01   339543.42
# 25 2005-02-01   358186.18
# 26 2005-03-01   374262.76
# 27 2005-04-01   261633.29
# 28 2005-05-01   457861.06

# %%
plt.plot(SalesMY["MonthYear"], SalesMY["SALES"])
plt.title("Sales by Month Year")
plt.ylabel("Sales")
plt.xlabel("Month-Year")
# Out:
# Text(0.5, 0, 'Month-Year')

# %%
fig = plt.figure(figsize=(15, 15)) 
plt.subplots_adjust(wspace=  0.25, hspace=0.25)

ax1 = fig.add_subplot(2,2,1)
ax1.bar(SalesperYr["YEAR_ID"], SalesperYr["SALES"], color=("blue", "red", "yellow"))
ax1.set_title("Sales per Year")
ax1.set_ylabel("Sales")
ax1.legend(labels=SalesperYr["YEAR_ID"])

ax2 = fig.add_subplot(2,2,2)
ax2.pie(topSales["SALES"], labels=topSales["COUNTRY"], autopct="%1.1f%%", startangle=90, explode=(0.1,0,0,0,0))
ax2.set_title("Top 5 Sales")

ax3 = fig.add_subplot(2,2, (3,4))
ax3.plot(SalesMY["MonthYear"], SalesMY["SALES"])
ax3.set_ylabel("Sales")
ax3.set_xlabel("Month-Year")
ax3.set_title("Sales by Month")

fig.show()
# Out:
# /var/folders/rj/cq5dfm_n2fl0lyxpgkdmt5gr0000gn/T/ipykernel_59061/2867947265.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dataSales.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE', 'MonthYear'],
#       dtype='object')

# %%
top10 = dataSales[["PRODUCTCODE","SALES"]].groupby("PRODUCTCODE")["SALES"].sum().reset_index()
top10 = top10.nlargest(10, ["SALES"])
top10
# Out:
#    PRODUCTCODE      SALES
# 39    S18_3232  288245.42
# 1     S10_1949  191073.03
# 3     S10_4698  170401.07
# 7     S12_1108  168585.32
# 25    S18_2238  154623.95
# 12    S12_3891  145332.04
# 76    S24_3856  140626.90
# 9     S12_2823  140006.16
# 21    S18_1662  139421.97
# 6     S12_1099  137177.01

# %%
plt.pie(top10["SALES"], labels=top10["PRODUCTCODE"],autopct="%1.1f%%", startangle=90)
plt.title("Top 5 Sales")
plt.show()
